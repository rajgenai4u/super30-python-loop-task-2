# %%
print("My Name is Rajesh")
# Out:
# My Name is Rajesh

# %%
10+50
# Out:
# 60

# %%
name = input("Enter your name: ")

# %%
print(f"Hello,{name},my Super30 environment is ready!")
# Out:
# Hello,Rajesh,my Super30 environment is ready!
