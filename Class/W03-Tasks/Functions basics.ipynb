# %%
#Objective

#Learn reusable programming using custom functions, arguments, parameters, return values, scope, and default arguments.

# %%
# def add(a, b) that returns the addition of two numbers.

def add_numbers(num1, num2):
    """This function takes two numbers as input and returns their sum."""
    return num1 + num2

# Example usage:
#result = add_numbers(5, 3)
num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))
result = add_numbers(num1, num2)
print("The sum is:", result)
# Out:
# The sum is: 55.0

# %%
# Create functions for addition subtraction multiplication division  

def add(a, b):
    return a + b

def subtract(a, b):
    return a - b

def multiply(a, b):
    return a * b

def divide(a, b):
    if b == 0:
        return "Error: Division by zero is not allowed."
    return a / b    

print("Select operation:")
print("1. Add")
print("2. Subtract")
print("3. Multiply")
print("4. Divide")  

print("Enter choice (1/2/3/4):")
choice = input()
print("Enter first number:")
num1 = float(input())
print("Enter second number:")
num2 = float(input())   
print("Result:")
if choice == '1':
    print(num1, "+", num2, "=", add(num1, num2))
elif choice == '2':
    print(num1, "-", num2, "=", subtract(num1, num2))
elif choice == '3':         
    print(num1, "*", num2, "=", multiply(num1, num2))
elif choice == '4':
    print(num1, "/", num2, "=", divide(num1, num2))
else:
    print("Invalid input")
# Out:
# Select operation:
# 1. Add
# 2. Subtract
# 3. Multiply
# 4. Divide
# Enter choice (1/2/3/4):
# Enter first number:
# Enter second number:
# Result:
# 34.0 / 7.0 = 4.857142857142857

# %%
# Create a function that determines whether a number is even or odd.

def is_even_add(n):
    """This function checks if a number is even or odd."""
    if n % 2 == 0:
        return "Given number is Even"
    else:
        return "Given number is Odd"
    
print("Enter a number to check if it is even or odd:")
number = int(input())
result = is_even_add(number)
print(result)
# Out:
# Enter a number to check if it is even or odd:
# Given number is Odd

# %%
#Create a function that returns the largest of three numbers without using max().

def find_largest(a, b, c):
    """This function returns the largest of three numbers."""
    if a >= b and a >= c:
        return a
    elif b >= a and b >= c:
        return b
    else:
        return c

print("Enter three numbers to find the largest:")
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
num3 = float(input("Enter third number: "))
largest = find_largest(num1, num2, num3)
print("The largest number is:", largest)
# Out:
# Enter three numbers to find the largest:
# The largest number is: 78.0

# %%
#Create a function that calculates factorial.
def calculate_factorial(n):
    """This function calculates the factorial of a number."""
    if n < 0:
        return "Error: Factorial is not defined for negative numbers."
    elif n == 0 or n == 1:
        return 1
    else:
        factorial = 1
        for i in range(2, n + 1):
            factorial *= i
        return factorial

print("Enter a number to calculate its factorial:")
number = int(input())
result = calculate_factorial(number)
print(result)
# Out:
# Enter a number to calculate its factorial:
# 120

# %%
#Create a function that calculates factorial. 
def factorial(n):
    """This function calculates the factorial of a number."""
    if n < 0:
        return "Error: Factorial is not defined for negative numbers."
    elif n == 0 or n == 1:
        fact= 1
        return fact
    else:
        fact = n * factorial(n - 1)
        return fact

print("Enter a number to calculate its factorial:")
number = int(input())
result = factorial(number)
print(result)
# Out:
# Enter a number to calculate its factorial:
# 3628800

# %%
#Create a function that checks whether a number is prime. 
def is_prime(n):
    """This function checks whether a number is prime."""
    if n < 2:
        return False
    is_prime = True
    for i in range(2, n):
        if n % i == 0:
            is_prime = False
            break
    return is_prime

print("Enter a number to check if it's prime:")
number = int(input())
if is_prime(number):
    print(f"{number} is a prime number.")
else:
    print(f"{number} is not a prime number.")
# Out:
# Enter a number to check if it's prime:
# 21 is not a prime number.

# %%
# Create def calculate_discount(price, discount=10) where the default discount is 10%.
def calculate_discount(price, discount=10):
    """
    Calculate the discounted price of an item.
    
    Parameters:
    price (float): The original price of the item.
    discount (float): The discount percentage (default is 10%).
    
    Returns:
    float: The discounted price.
    """
    discounted_price = price - (price * discount / 100)
    return discounted_price

# Example usage:
original_price = float(input("Enter the original price of the item: "))
discounted_price = calculate_discount(original_price)
print(f"The discounted price is: ${discounted_price:.2f}")
# Out:
# The discounted price is: $315.00

# %%
#Create a function that accepts a list and returns its sum without using sum(). 
def calculate_sum(numbers):
    """This function calculates the sum of a list of numbers without using the built-in sum() function."""
    total = 0
    for num in numbers:
        total += num
    return total

print("Enter the count of numbers you want to sum:")
count = int(input())
numbers = []
for i in range(count):
    num = float(input(f"Enter number {i + 1}: "))
    numbers.append(num)
result = calculate_sum(numbers)
print("the length of the list is:", len(numbers))
print("the entered list is:", numbers)
print("The sum of the list is:", result)
# Out:
# Enter the count of numbers you want to sum:
# the length of the list is: 5
# the entered list is: [10.0, 40.0, 20.0, 60.0, 80.0]
# The sum of the list is: 210.0

# %%
#Create a function that accepts a string and returns the number of vowels.
def count_vowels(s):
    vowels = "aeiouAEIOU"
    count = 0
    for char in s:
        if char in vowels:
            count += 1
    return count

# Example usage:
input_string = input("Enter a string: ")
vowel_count = count_vowels(input_string)
#print(f"The number of vowels in the string '{input_string}' is: {vowel_count}")
print("The number of vowels in the string" ,input_string ,"is:", vowel_count)
# Out:
# The number of vowels in the string Rajesh is: 2

# %%
# Create a function that accepts a string and determines whether it is a palindrome.
def is_palindrome(s):
    # Remove non-alphanumeric characters and convert to lowercase
    """cleaned = ''.join(c.lower() for c in s if c.isalnum())
    This line cleans and normalizes the text using three steps:

    It iterates through each character `c` in the input string `s`.It checks if the character is 
    alphanumeric (letters and numbers) using `c.isalnum()`.If it is, it converts the character to 
    lowercase using `c.lower()`.

1.c in s if c.isalnum(): Iterates through each character c in the string s and 
keeps it only if it is alphanumeric (letters and numbers). Spaces, punctuation, 
and symbols (e.g., ,, !, :) are filtered out.

2.c.lower(): Converts every kept character to lowercase so the check is case-insensitive 
    ('R' and 'r' are treated as identical).

3. ''.join(...): Combines all the filtered, lowercase characters back into a single string.

Example:

If s = "Race Car!", cleaned becomes "racecar".
    """
    cleaned = ''.join(c.lower() for c in s if c.isalnum())
    # Check if the cleaned string is equal to its reverse
    return cleaned == cleaned[::-1]

# Example usage:
input_string = input("Enter a string: ")
if is_palindrome(input_string):
    print(f"'{input_string}' is a palindrome.")
else:
    print(f"'{input_string}' is not a palindrome.")
# Out:
# 'Rajesh' is not a palindrome.

# %%
# Create a function that accepts name age course and returns a formatted student profile.Use both positional and keyword arguments while calling it. 
def student_profile(name, age, course):
    """This function returns a formatted student profile."""
    return f"Student Name: {name}\nAge: {age}\nCourse: {course}"

# Example usage with positional arguments:
print(student_profile("Alice", 20, "Computer Science"))

# Example usage with keyword arguments:
print(student_profile(name="Bob", age=22, course="Mathematics"))
# Out:
# Student Name: Alice
# Age: 20
# Course: Computer Science
# Student Name: Bob
# Age: 22
# Course: Mathematics

# %%
# Demonstrate the difference between a function that uses print() a function that uses return Explain through code why return is useful. 

def print_profile(name, age, course):
    print(f"Student Name: {name}")
    print(f"Age: {age}")
    print(f"Course: {course}")

def return_profile(name, age, course):
    return f"Student Name: {name}\nAge: {age}\nCourse: {course}"

# Example usage:
print_profile("Alice", 20, "Computer Science")
print()
print(return_profile("Alice", 20, "Computer Science"))

"""  
In the first function, print_profile(), the information is printed directly to the console.
In the second function, return_profile(), the information is returned as a string, which can be 
stored in a variable, printed, or used in further computations. 
This makes return more versatile than print

print() displays output to the console for a human to see, but returns None to the program. r
eturn hands a value back to the caller so it can be saved in a variable, passed to other functions, 
or used in further calculations.

Here is the practical demonstration in code:

def add_with_print(a, b):
    """Prints the sum directly to the console (returns None)."""
    print(a + b)


def add_with_return(a, b):
    """Returns the sum so it can be re-used elsewhere."""
    return a + b


# --- 1. Basic Function Call Output ---
print("--- Using print() ---")
add_with_print(5, 5)  # Displays 10 on the screen

print("\n--- Using return ---")
result = add_with_return(5, 5)  # No output yet! The value 10 is stored in 'result'
print(result)  # Displays 10 on the screen 

Why return is Useful:
-----------------------
return makes functions modular and reusable. When a function returns a value, that result can be 
chained into further logic, which is impossible with print().

# --- Scenario: Calculate a 10% tax on the result ---


# ATTEMPT A: Using print() - FAILS
def calculate_tax_fail():
    val = add_with_print(100, 50)  # Prints 150, but 'val' receives None
    # tax = val * 0.10  <-- TypeError: unsupported operand type(s) for *: 'NoneType' and 'float'


# ATTEMPT B: Using return - WORKS
def calculate_tax_success():
    val = add_with_return(100, 50)  # 'val' receives the number 150
    tax = val * 0.10  # 150 * 0.10 = 15.0
    final_total = val + tax  # 150 + 15.0 = 165.0
    return final_total


print("Final Total with Tax:", calculate_tax_success())
# Output: Final Total with Tax: 165.0

Key Differences:
--------------------
print(): Used for debugging, user interfaces, or logs. Its output cannot be stored or processed 
further by Python code.

return: Used to send data back to the rest of your program. It enables mathematical operations, 
string formatting, and chaining multiple functions together.

"""
