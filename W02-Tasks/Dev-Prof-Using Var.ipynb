# %%
# Declare variables with developer profile details
name = "Karre Rajesh"
age = 45
city = "Kuala Lumpur"
organization = "Tech Euron"
learning_topic = "Basic Python"
years_of_experience = 18
likes_python = True
expected_salary = 7500000.00

# Print every value & data tyoe of every variable
print("--- Developer Details & Data Types ---")

print("Name:", name)
print("Type:", type(name))

print("Age:", age)
print("Type:", type(age))

print("City:", city)
print("Type:", type(city))

print("College/Company:", organization)
print("Type:", type(organization))

print("Current Learning Topic:", learning_topic)
print("Type:", type(learning_topic), "\n")

print("Years of Experience/Study:", years_of_experience)
print("Type:", type(years_of_experience), "\n")

print("Likes Python:", likes_python)
print("Type:", type(likes_python), "\n")

print("Expected Salary:", expected_salary)
print("Type:", type(expected_salary))
# Out:
# --- Developer Details & Data Types ---
# Name: Karre Rajesh
# Type: <class 'str'>
# Age: 45
# Type: <class 'int'>
# City: Kuala Lumpur
# Type: <class 'str'>
# College/Company: Tech Euron
# Type: <class 'str'>
# Current Learning Topic: Basic Python
# Type: <class 'str'>
#
# Years of Experience/Study: 18
# Type: <class 'int'>
#
# Likes Python: True
# Type: <class 'bool'>
#
# Expected Salary: 7500000.0
# Type: <class 'float'>
